# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, Conv2D, Dropout, MaxPool2D, Flatten

x = pd.read_csv('x2.csv', index_col=0)
y = pd.read_csv('y2.csv', index_col=0)
y = y.iloc[:,-1]
# 전처리
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x) 
x = scaler.transform(x)

from keras.utils import np_utils
y = np_utils.to_categorical(y)

# %%
x.shape
# Out:
# (1994, 60)

# %%
x = np.array(x)

# %%
y.shape
# Out:
# (1994, 6)

# %%
y = np.array(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=43)

model = Sequential()
model.add(Dense(52, input_shape=(60,))) 
model.add(Dense(228))
model.add(Dense(356))
model.add(Dropout(0.2))
model.add(Dense(250))
model.add(Dense(164))
model.add(Dropout(0.4))
model.add(Dense(64))
model.add(Dense(6, activation='softmax')) 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc']) 
model.fit(x_train,y_train, epochs=550, batch_size=50)
loss, acc = model.evaluate(x_test,y_test) 
print('loss 는',loss)
print('acc 는',acc)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_95 (Dense)             (None, 52)                3172
# _________________________________________________________________
# dense_96 (Dense)             (None, 228)               12084
# _________________________________________________________________
# dense_97 (Dense)             (None, 356)               81524
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 356)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 250)               89250
# _________________________________________________________________
# dense_99 (Dense)             (None, 164)               41164
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 164)               0
# ...

# %%
x2 = x.reshape(1994,60,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x2,y, test_size=0.2, random_state=43)

model = Sequential()
model.add(LSTM(52, input_shape=(60,1))) 
model.add(Dense(80))
model.add(Dense(100))
model.add(Dropout(0.2))
model.add(Dense(100))
model.add(Dense(164))
model.add(Dropout(0.8))
model.add(Dense(16))
model.add(Dense(6, activation='softmax')) 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc']) 
model.fit(x_train,y_train, epochs=250, batch_size=50)
loss, acc = model.evaluate(x_test,y_test) 
print('loss 는',loss)
print('acc 는',acc)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_8 (LSTM)                (None, 52)                11232
# _________________________________________________________________
# dense_102 (Dense)            (None, 80)                4240
# _________________________________________________________________
# dense_103 (Dense)            (None, 100)               8100
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 100)               10100
# _________________________________________________________________
# ...

# %%
x3 = x.reshape(1994,60,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x2,y, test_size=0.2, random_state=43)

model = Sequential()
model.add(LSTM(120, input_shape=(60,1))) 
model.add(Dense(228))
model.add(Dense(356))
model.add(Dropout(0.2))
model.add(Dense(250))
model.add(Dense(164))
model.add(Dropout(0.4))
model.add(Dense(64))
model.add(Dense(6, activation='relu')) 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc']) 
model.fit(x_train,y_train, epochs=500, batch_size=50)
loss, acc = model.evaluate(x_test,y_test) 
print('loss 는',loss)
print('acc 는',acc)
