# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

# %%
# krx에서 상장기업 리스트 가져오기
stock_df = pd.read_html( 'http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
stock_df['종목코드'] = stock_df['종목코드'].map(lambda x: f'{x:0>6}')
corp_list = stock_df[['회사명','종목코드','업종','지역']]
corp_list
# Out:
#             회사명    종목코드               업종     지역
# 0           DSR  155660      1차 비철금속 제조업  부산광역시
# 1            GS  078930           기타 금융업  서울특별시
# 2         GS글로벌  001250        상품 종합 도매업  서울특별시
# 3     HDC현대산업개발  294870           건물 건설업  서울특별시
# 4         LG이노텍  011070         전자부품 제조업  서울특별시
# ...         ...     ...              ...    ...
# 2348    지앤이헬스케어  299480      기타 섬유제품 제조업    경기도
# 2349         코셋  189350   통신 및 방송 장비 제조업  광주광역시
# 2350         툴젠  199800  자연과학 및 공학 연구개발업  서울특별시
# 2351   한국미라클피플사  331660      기타 화학제품 제조업    경기도
# 2352        휴벡셀  212310       의료용 기기 제조업    경기도
#
# [2353 rows x 4 columns]

# %%
rating_box = pd.read_csv('rating_box.csv', index_col=None)

# %%
종목코드 = corp_list[['회사명','종목코드']]
종목코드
# Out:
#             회사명    종목코드
# 0           DSR  155660
# 1            GS  078930
# 2         GS글로벌  001250
# 3     HDC현대산업개발  294870
# 4         LG이노텍  011070
# ...         ...     ...
# 2348    지앤이헬스케어  299480
# 2349         코셋  189350
# 2350         툴젠  199800
# 2351   한국미라클피플사  331660
# 2352        휴벡셀  212310
#
# [2353 rows x 2 columns]

# %%
table = pd.merge(rating_box,종목코드,how='inner',on='회사명')
table
# Out:
#       Unnamed: 0        회사명         네임   복지  워라벨 사내문화  가능성  경영진 총만족도    종목코드
# 0              0         GS         GS  3.9  3.3  3.4  3.3  2.8  3.5  078930
# 1              0         GS         GS  3.9  3.3  3.4  3.3  2.8  3.5  078930
# 2              0        DSR        DSR  3.1  2.1  2.3  2.5  2.2  2.6  155660
# 3              0      GS글로벌      GS글로벌  3.1  2.4  2.1  2.7  2.3  2.7  001250
# 4              0  HDC현대산업개발  HDC현대산업개발  3.5  3.2  3.2  3.1  2.8  3.5  294870
# ...          ...        ...        ...  ...  ...  ...  ...  ...  ...     ...
# 2122           0        이노진        이노진  1.8  2.7  2.4  2.3  1.5  2.0  344860
# 2123           0         코셋         코셋  2.3  2.3  3.3  4.0  3.0  3.3  189350
# 2124           0         툴젠         툴젠  2.6  3.3  2.7  2.4  2.2  2.6  199800
# 2125           0   한국미라클피플사   한국미라클피플사  2.0  3.9  2.0  1.7  1.6  1.7  331660
# 2126           0        휴벡셀        휴벡셀  1.7  2.7  2.2  2.3  1.7  2.3  212310
#
# [2127 rows x 10 columns]

# %%
code_list = list(table['종목코드'])

# %%
df = pd.DataFrame(index=range(0,2500),columns = ['종목코드','매출액_1903','매출액_1906','매출액_1909','매출액_1912','매출액_2003',
                                        '영업이익_1903','영업이익_1906','영업이익_1909','영업이익_1912','영업이익_2003',
                                        '당기순이익_1903','당기순이익_1906','당기순이익_1909','당기순이익_1912','당기순이익_2003',
                                        '영업이익률_1903','영업이익률_1906','영업이익률_1909','영업이익률_1912','영업이익률_2003',
                                        '순이익률_1903','순이익률_1906','순이익률_1909','순이익률_1912','순이익률_2003',
                                        'roe_1903','roe_1906','roe_1909','roe_1912','roe_2003',
                                        '부채비율_1903','부채비율_1906','부채비율_1909','부채비율_1912','부채비율_2003',
                                        '당좌비율_1903','당좌비율_1906','당좌비율_1909','당좌비율_1912','당좌비율_2003',
                                        '유보율_1903','유보율_1906','유보율_1909','유보율_1912','유보율_2003',
                                        'eps_1903','eps_1906','eps_1909','eps_1912','eps_2003',
                                        'per_1903','per_1906','per_1909','per_1912','per_2003',
                                        'bps_1903','bps_1906','bps_1909','bps_1912','bps_2003',
                                        'pbr_1903','pbr_1906','pbr_1909','pbr_1912','pbr_2003',])

# %%
df['당기순이익/매출액_1903'] = df.loc[i,'당기순이익_1903']/df.loc[i,'매출액_1903']
df['당기순이익/매출액_1906'] = df.loc[i,'당기순이익_1906']/df.loc[i,'매출액_1906']
df['당기순이익/매출액_1909'] = df.loc[i,'당기순이익_1909']/df.loc[i,'매출액_1909']
df['당기순이익/매출액_1912'] = df.loc[i,'당기순이익_1912']/df.loc[i,'매출액_1923']
df['당기순이익/매출액_2003'] = df.loc[i,'당기순이익_2003']/df.loc[i,'매출액_2003']


df['당기순이익/영업이익_1903'] = df.loc[i,'당기순이익_1903']/df.loc[i,'영업이익_1903']
df['당기순이익/영업이익_1903'] = df.loc[i,'당기순이익_1906']/df.loc[i,'영업이익_1906']
df['당기순이익/영업이익_1903'] = df.loc[i,'당기순이익_1909']/df.loc[i,'영업이익_1909']
df['당기순이익/영업이익_1903'] = df.loc[i,'당기순이익_1912']/df.loc[i,'영업이익_1912']
df['당기순이익/영업이익_2003'] = df.loc[i,'당기순이익_2003']/df.loc[i,'영업이익_2003']

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
num = 0
for a in code_list :
    
    try:
        driver.get('https://finance.naver.com/item/main.nhn?code='+a)
        html = driver.page_source
        soup = BeautifulSoup(html)
        trs = soup.find_all("tr")
        list=[a]
        for j in range(22,35) :
            per = trs[j]
            per1 = per.find_all("td")
            for i in range(4,9) :
    #             print(per1[i].text.replace('\n','').replace('\t','') )
                list.append(per1[i].text.replace('\n','').replace('\t',''))
        df.iloc[num] = list
        num += 1
        time.sleep(0.5)
    
    except : continue

# %%
len(code_list)
# Out:
# 2127

# %%
df.to_csv('financial_data.csv')

# %%
df = df.iloc[:1995,:]
df
# Out:
#         종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003 영업이익_1903 영업이익_1906  \
# 0     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 1     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 2     155660      560      624      584      596      584        23        28
# 3     001250   10,431   11,137    9,126    8,199    8,682       153       177
# 4     294870    8,810   14,492    8,714   10,149   10,067     1,015     1,958
# ...      ...      ...      ...      ...      ...      ...       ...       ...
# 1990  034810       45       53       51       53       52         6         8
# 1991  076610    1,003      934      829      726      847        36        25
# 1992  060560      548      619      657      832      603        -7        -1
# 1993  134780      220      124      125      100      236       -42        -8
# 1994  238490      284      167      207      193      317       105       -27
#
# ...

# %%
int(df.loc[0,'당기순이익_1903'].replace(',',''))
# Out:
# 2058

# %%
round(int(df.loc[0,'당기순이익_1903'].replace(',',''))/int(df.loc[0,'매출액_1903'].replace(',','')),3)
# Out:
# 0.047

# %%
df
# Out:
#         종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003 영업이익_1903 영업이익_1906  \
# 0     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 1     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 2     155660      560      624      584      596      584        23        28
# 3     001250   10,431   11,137    9,126    8,199    8,682       153       177
# 4     294870    8,810   14,492    8,714   10,149   10,067     1,015     1,958
# ...      ...      ...      ...      ...      ...      ...       ...       ...
# 1990  034810       45       53       51       53       52         6         8
# 1991  076610    1,003      934      829      726      847        36        25
# 1992  060560      548      619      657      832      603        -7        -1
# 1993  134780      220      124      125      100      236       -42        -8
# 1994  238490      284      167      207      193      317       105       -27
#
# ...

# %%
df1 = df.copy()
df1
# Out:
#         종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003 영업이익_1903 영업이익_1906  \
# 0     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 1     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 2     155660      560      624      584      596      584        23        28
# 3     001250   10,431   11,137    9,126    8,199    8,682       153       177
# 4     294870    8,810   14,492    8,714   10,149   10,067     1,015     1,958
# ...      ...      ...      ...      ...      ...      ...       ...       ...
# 1990  034810       45       53       51       53       52         6         8
# 1991  076610    1,003      934      829      726      847        36        25
# 1992  060560      548      619      657      832      603        -7        -1
# 1993  134780      220      124      125      100      236       -42        -8
# 1994  238490      284      167      207      193      317       105       -27
#
# ...

# %%
df
# Out:
#         종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003 영업이익_1903 영업이익_1906  \
# 0     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 1     078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 2     155660      560      624      584      596      584        23        28
# 3     001250   10,431   11,137    9,126    8,199    8,682       153       177
# 4     294870    8,810   14,492    8,714   10,149   10,067     1,015     1,958
# ...      ...      ...      ...      ...      ...      ...       ...       ...
# 1990  034810       45       53       51       53       52         6         8
# 1991  076610    1,003      934      829      726      847        36        25
# 1992  060560      548      619      657      832      603        -7        -1
# 1993  134780      220      124      125      100      236       -42        -8
# 1994  238490      284      167      207      193      317       105       -27
#
# ...

# %%
df = pd.read_csv('financial_data_원본.csv')

# %%
df = df.iloc[:1995,:]

# %%
for i in range(len(df)) :
    try:
        df.loc[i,'당기순이익/매출액_1903'] = round(int(df.loc[i,'당기순이익_1903'].replace(',',''))/int(df.loc[i,'매출액_1903'].replace(',','')),3)
        df.loc[i,'당기순이익/매출액_1906'] = round(int(df.loc[i,'당기순이익_1906'].replace(',',''))/int(df.loc[i,'매출액_1906'].replace(',','')),3)
        df.loc[i,'당기순이익/매출액_1909'] = round(int(df.loc[i,'당기순이익_1909'].replace(',',''))/int(df.loc[i,'매출액_1909'].replace(',','')),3)
        df.loc[i,'당기순이익/매출액_1912'] = round(int(df.loc[i,'당기순이익_1912'].replace(',',''))/int(df.loc[i,'매출액_1912'].replace(',','')),3)
#         df.loc[i,'당기순이익/매출액_2003'] = round(int(df.loc[i,'당기순이익_2003'].replace(',',''))/int(df.loc[i,'매출액_2003'].replace(',','')),3)

        df.loc[i,'당기순이익/영업이익_1903'] = round(int(df.loc[i,'당기순이익_1903'].replace(',',''))/int(df.loc[i,'영업이익_1903'].replace(',','')),3)
        df.loc[i,'당기순이익/영업이익_1906'] = round(int(df.loc[i,'당기순이익_1906'].replace(',',''))/int(df.loc[i,'영업이익_1906'].replace(',','')),3)
        df.loc[i,'당기순이익/영업이익_1909'] = round(int(df.loc[i,'당기순이익_1909'].replace(',',''))/int(df.loc[i,'영업이익_1909'].replace(',','')),3)
        df.loc[i,'당기순이익/영업이익_1912'] = round(int(df.loc[i,'당기순이익_1912'].replace(',',''))/int(df.loc[i,'영업이익_1912'].replace(',','')),3)
#         df.loc[i,'당기순이익/영업이익_2003'] = round(int(df.loc[i,'당기순이익_2003'].replace(',',''))/int(df.loc[i,'영업이익_2003'].replace(',','')),3)
        
    except: continue

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# 종목코드                 0
# 매출액_1903            28
# 매출액_1906            10
# 매출액_1909             4
#                   ...
# 당기순이익/매출액_1912     171
# 당기순이익/영업이익_1903    198
# 당기순이익/영업이익_1906    225
# 당기순이익/영업이익_1909    253
# 당기순이익/영업이익_1912    272
# Length: 75, dtype: int64

# %%
df
# Out:
#       Unnamed: 0      종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003  \
# 0              0   78930.0   44,187   45,081   45,234   43,359   41,961
# 1              1   78930.0   44,187   45,081   45,234   43,359   41,961
# 2              2  155660.0      560      624      584      596      584
# 3              3    1250.0   10,431   11,137    9,126    8,199    8,682
# 4              4  294870.0    8,810   14,492    8,714   10,149   10,067
# ...          ...       ...      ...      ...      ...      ...      ...
# 1990        1990   34810.0       45       53       51       53       52
# 1991        1991   76610.0    1,003      934      829      726      847
# 1992        1992   60560.0      548      619      657      832      603
# 1993        1993  134780.0      220      124      125      100      236
# 1994        1994  238490.0      284      167      207      193      317
#
#      영업이익_1903 영업이익_1906 영업이익_1909  ... pbr_1912 pbr_2003 당기순이익/매출액_1903  \
# ...

# %%
df.to_csv('financial_data.csv')

# %%
df.iloc[:10]
# Out:
#      종목코드 매출액_1903 매출액_1906 매출액_1909 매출액_1912 매출액_2003 영업이익_1903 영업이익_1906  \
# 0  078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 1  078930   44,187   45,081   45,234   43,359   41,961     5,127     4,878
# 2  155660      560      624      584      596      584        23        28
# 3  001250   10,431   11,137    9,126    8,199    8,682       153       177
# 4  294870    8,810   14,492    8,714   10,149   10,067     1,015     1,958
# 5  011070   13,686   15,223   24,459   29,652   20,109      -114       188
# 6  066570  149,151  156,293  157,006  160,612  147,278     9,006     6,522
# 7  010060    6,418    6,539    6,708    6,387    5,686      -401      -199
# 8  100840      333      600      713      488      561        20        66
# 9  064960    2,255    2,523    2,398    2,587    2,165       139       227
#
#   영업이익_1909 영업이익_1912  ... bps_1903 bps_1906 bps_1909 bps_1912 bps_2003  \
# ...

# %%
html = driver.page_source
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36" lang="ko"><head>
# <title>GS : 네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="https://finance.naver.com/item/main.nhn?code=078930" property="og:url"/>
# <meta content="GS - 네이버 금융 : 네이버 금융" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버금융" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
trs = soup.find_all("tr")

# %%
len(trs)
# Out:
# 119

# %%
dict = {'매출액(억원)_201903':[corp[1]],'네임':[name],'복지':[welfare],'워라벨':[balance],'사내문화':[culture],'가능성':[possibility],'경영진':[executive],'총만족도':[total]}
rating_box = pd.DataFrame(dict)

# %%
list=[code_list[0]]

# %%
list
# Out:
# ['078930']

# %%
list=[code_list[0]]
for j in range(22,35) :
    per = trs[j]
    per1 = per.find_all("td")
    for i in range(4,9) :
        print(per1[i].text.replace('\n','').replace('\t','') )
        list.append(per1[i].text.replace('\n','').replace('\t',''))
# Out:
# 44,187
# 45,081
# 45,234
# 43,359
# 41,961
# 5,127
# 4,878
# 5,511
# 4,815
# 95
# 2,058
# 2,013
# 2,436
# 183
# -2,952
# 11.60
# 10.82
# 12.18
# 11.11
# 0.22
# 4.66
# 4.46
# 5.38
# 0.42
# -7.04
# 10.28
# 9.60
# 8.11
# 6.26
# 0.58
# 129.46
# 127.30
# 120.22
# 124.91
# 132.09
# 48.77
# 52.94
# 52.25
# 47.11
# 55.40
# 2,340.97
# 2,375.43
# 2,419.27
# 2,420.64
# 2,311.18
# 1,657
# 1,691
# 2,183
# 213
# -3,571
# 5.97
# 6.04
# 6.80
# 8.98
# 71.32
# 89,946
# 91,996
# 94,731
# 93,771
# 89,099
# 0.59
# 0.56
# 0.53
# 0.55
# 0.41

# %%
list
# Out:
# ['078930',
#  '44,187',
#  '45,081',
#  '45,234',
#  '43,359',
#  '41,961',
#  '5,127',
#  '4,878',
#  '5,511',
#  '4,815',
#  '95',
#  '2,058',
#  '2,013',
#  '2,436',
#  '183',
#  '-2,952',
#  '11.60',
#  '10.82',
#  '12.18',
#  '11.11',
#  '0.22',
#  '4.66',
#  '4.46',
#  '5.38',
#  '0.42',
#  '-7.04',
#  '10.28',
#  '9.60',
#  '8.11',
#  '6.26',
#  '0.58',
#  '129.46',
#  '127.30',
#  '120.22',
#  '124.91',
#  '132.09',
#  '48.77',
#  '52.94',
#  '52.25',
#  '47.11',
#  '55.40',
#  '2,340.97',
#  '2,375.43',
#  '2,419.27',
#  '2,420.64',
#  '2,311.18',
#  '1,657',
#  '1,691',
#  '2,183',
#  '213',
#  '-3,571',
#  '5.97',
#  '6.04',
#  '6.80',
#  '8.98',
#  '71.32',
#  '89,946',
#  '91,996',
#  '94,731',
#  '93,771',
#  '89,099',
#  '0.59',
#  '0.56',
#  '0.53',
#  '0.55',
#  '0.41']

# %%
df
# Out:
# Empty DataFrame
# Columns: [종목코드, 매출액_1903, 매출액_1906, 매출액_1909, 매출액_1912, 매출액_2003, 영업이익_1903, 영업이익_1906, 영업이익_1909, 영업이익_1912, 영업이익_2003, 당기순이익_1903, 당기순이익_1906, 당기순이익_1909, 당기순이익_1912, 당기순이익_2003, 영업이익률_1903, 영업이익률_1906, 영업이익률_1909, 영업이익률_1912, 영업이익률_2003, 순이익률_1903, 순이익률_1906, 순이익률_1909, 순이익률_1912, 순이익률_2003, roe_1903, roe_1906, roe_1909, roe_1912, roe_2003, 부채비율_1903, 부채비율_1906, 부채비율_1909, 부채비율_1912, 부채비율_2003, 당좌비율_1903, 당좌비율_1906, 당좌비율_1909, 당좌비율_1912, 당좌비율_2003, 유보율_1903, 유보율_1906, 유보율_1909, 유보율_1912, 유보율_2003, eps_1903, eps_1906, eps_1909, eps_1912, eps_2003, per_1903, per_1906, per_1909, per_1912, per_2003, bps_1903, bps_1906, bps_1909, bps_1912, bps_2003, pbr_1903, pbr_1906, pbr_1909, pbr_1912, pbr_2003]
# Index: []
#
# [0 rows x 66 columns]

# %%
len(list)
# Out:
# 66

# %%
df.append(pd.DataFrame(list))
# Out:
#          0 bps_1903 bps_1906 bps_1909 bps_1912 bps_2003 eps_1903 eps_1906  \
# 0   078930      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   44,187      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   45,081      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3   45,234      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4   43,359      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 61    0.59      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 62    0.56      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 63    0.53      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 64    0.55      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 65    0.41      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    eps_1909 eps_1912  ... 영업이익률_1906 영업이익률_1909 영업이익률_1912 영업이익률_2003  \
# ...

# %%
len(df.columns)
# Out:
# 66

# %%
df.iloc[0,:] = list
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-90c2d072791f> in <module>
# ----> 1 df.iloc[0,:] = list
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     667         else:
#     668             key = com.apply_if_callable(key, self.obj)
# --> 669         indexer = self._get_setitem_indexer(key)
#     670         self._setitem_with_indexer(indexer, value)
#     671
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     645         if isinstance(key, tuple):
#     646             try:
# --> 647                 return self._convert_tuple(key)
#     648             except IndexingError:
#     649                 pass
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_tuple(self, key)
#     730                 if i >= self.ndim:
# ...

# %%
df = pd.DataFrame(, index=0columns = ['종목코드','매출액_1903','매출액_1906','매출액_1909','매출액_1912','매출액_2003',
                                        '영업이익_1903','영업이익_1906','영업이익_1909','영업이익_1912','영업이익_2003',
                                        '당기순이익_1903','당기순이익_1906','당기순이익_1909','당기순이익_1912','당기순이익_2003',
                                        '영업이익률_1903','영업이익률_1906','영업이익률_1909','영업이익률_1912','영업이익률_2003',
                                        '순이익률_1903','순이익률_1906','순이익률_1909','순이익률_1912','순이익률_2003',
                                        'roe_1903','roe_1906','roe_1909','roe_1912','roe_2003',
                                        '부채비율_1903','부채비율_1906','부채비율_1909','부채비율_1912','부채비율_2003',
                                        '당좌비율_1903','당좌비율_1906','당좌비율_1909','당좌비율_1912','당좌비율_2003',
                                        '유보율_1903','유보율_1906','유보율_1909','유보율_1912','유보율_2003',
                                        'eps_1903','eps_1906','eps_1909','eps_1912','eps_2003',
                                        'per_1903','per_1906','per_1909','per_1912','per_2003',
                                        'bps_1903','bps_1906','bps_1909','bps_1912','bps_2003',
                                        'pbr_1903','pbr_1906','pbr_1909','pbr_1912','pbr_2003',])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-1ba14589bf85> in <module>
#      11                                         'per_1903','per_1906','per_1909','per_1912','per_2003',
#      12                                         'bps_1903','bps_1906','bps_1909','bps_1912','bps_2003',
# ---> 13                                         'pbr_1903','pbr_1906','pbr_1909','pbr_1912','pbr_2003',], index=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [종목코드, 매출액_1903, 매출액_1906, 매출액_1909, 매출액_1912, 매출액_2003, 영업이익_1903, 영업이익_1906, 영업이익_1909, 영업이익_1912, 영업이익_2003, 당기순이익_1903, 당기순이익_1906, 당기순이익_1909, 당기순이익_1912, 당기순이익_2003, 영업이익률_1903, 영업이익률_1906, 영업이익률_1909, 영업이익률_1912, 영업이익률_2003, 순이익률_1903, 순이익률_1906, 순이익률_1909, 순이익률_1912, 순이익률_2003, roe_1903, roe_1906, roe_1909, roe_1912, roe_2003, 부채비율_1903, 부채비율_1906, 부채비율_1909, 부채비율_1912, 부채비율_2003, 당좌비율_1903, 당좌비율_1906, 당좌비율_1909, 당좌비율_1912, 당좌비율_2003, 유보율_1903, 유보율_1906, 유보율_1909, 유보율_1912, 유보율_2003, eps_1903, eps_1906, eps_1909, eps_1912, eps_2003, per_1903, per_1906, per_1909, per_1912, per_2003, bps_1903, bps_1906, bps_1909, bps_1912, bps_2003, pbr_1903, pbr_1906, pbr_1909, pbr_1912, pbr_2003]
# Index: []
#
# [0 rows x 66 columns]

# %%
df.append(pd.DataFrame(list), columns=list(df.columns))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-07544ff5d475> in <module>
# ----> 1 df.append(pd.DataFrame(list), columns=list(df.columns))
#
# TypeError: 'list' object is not callable

# %%
df
# Out:
# Empty DataFrame
# Columns: [종목코드, 매출액_1903, 매출액_1906, 매출액_1909, 매출액_1912, 매출액_2003, 영업이익_1903, 영업이익_1906, 영업이익_1909, 영업이익_1912, 영업이익_2003, 당기순이익_1903, 당기순이익_1906, 당기순이익_1909, 당기순이익_1912, 당기순이익_2003, 영업이익률_1903, 영업이익률_1906, 영업이익률_1909, 영업이익률_1912, 영업이익률_2003, 순이익률_1903, 순이익률_1906, 순이익률_1909, 순이익률_1912, 순이익률_2003, roe_1903, roe_1906, roe_1909, roe_1912, roe_2003, 부채비율_1903, 부채비율_1906, 부채비율_1909, 부채비율_1912, 부채비율_2003, 당좌비율_1903, 당좌비율_1906, 당좌비율_1909, 당좌비율_1912, 당좌비율_2003, 유보율_1903, 유보율_1906, 유보율_1909, 유보율_1912, 유보율_2003, eps_1903, eps_1906, eps_1909, eps_1912, eps_2003, per_1903, per_1906, per_1909, per_1912, per_2003, bps_1903, bps_1906, bps_1909, bps_1912, bps_2003, pbr_1903, pbr_1906, pbr_1909, pbr_1912, pbr_2003]
# Index: []
#
# [0 rows x 66 columns]

# %%
df.iloc[0] =
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-127-a6b3f8434182> in <module>
# ----> 1 df.iloc[0] = list
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     667         else:
#     668             key = com.apply_if_callable(key, self.obj)
# --> 669         indexer = self._get_setitem_indexer(key)
#     670         self._setitem_with_indexer(indexer, value)
#     671
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     654         axis = self.axis or 0
#     655         try:
# --> 656             return self._convert_to_indexer(key, axis=axis)
#     657         except TypeError as e:
#     658
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, raise_missing)
#    2152
#    2153         try:
# ...

# %%
# per
per = trs[22]
per1 = per.find_all("td")
len(per1)
for i in range(4,9) :
    print(per1[i].text.replace('\n','').replace('\t','') )
# Out:
# 44,187
# 45,081
# 45,234
# 43,359
# 41,961

# %%
# per
per = trs[31]
per1 = per.find_all("td")
len(per1)
for i in range(4,9) :
    print(per1[i].text.replace('\n','').replace('\t','') )
# Out:
# 1,657
# 1,691
# 2,183
# 213
# -3,571

# %%
# per
per = trs[32]
per1 = per.find_all("td")
len(per1)
for i in range(4,9) :
    print(per1[i].text.replace('\n','').replace('\t','') )
# Out:
# 5.97
# 6.04
# 6.80
# 8.98
# 71.32

# %%
# bps
bps = trs[33]
bps1 = bps.find_all("td")
len(per1)
for i in range(4,9) :
    print(bps1[i].text.replace('\n','').replace('\t','') )
# Out:
# 89,946
# 91,996
# 94,731
# 93,771
# 89,099

# %%
# pbr
pbr = trs[34]
pbr1 = pbr.find_all("td")
len(per1)
for i in range(4,9) :
    print(pbr1[i].text.replace('\n','').replace('\t','') )
# Out:
# 0.59
# 0.56
# 0.53
# 0.55
# 0.41

# %%
per1[i]

# %%
per1[0].text.replace('\n','').replace('\t','')
# Out:
# '5.97'

# %%
per1[1].text.replace('\n','').replace('\t','')
# Out:
# '5.41'

# %%
per1[3].text.replace('\n','').replace('\t','')
# Out:
# '8.79'

# %%
per1[4].text.replace('\n','').replace('\t','')
# Out:
# '5.97'

# %%
trs[46]
# Out:
# <tr>
# <th class="h_th2 th_cop_comp15" scope="row"><span>조정영업이익(억)</span></th>
# <td>95</td>
# <td>-17,752</td>
# <td>-10,073</td>
# <td>-4,872</td>
# <td>822</td>
# </tr>

# %%
trs[47]
# Out:
# <tr>
# <th class="h_th2 th_cop_comp9" scope="row"><span>영업이익증가율(%)</span></th>
# <td>-98.04</td>
# <td>-1,705.83</td>
# <td>-10,709.43</td>
# <td>-584.27</td>
# <td>97.21</td>
# </tr>

# %%
trs[48]
# Out:
# <tr>
# <th class="h_th2 th_cop_comp10" scope="row"><span>당기순이익(억)</span></th>
# <td>-2,952</td>
# <td>-15,522</td>
# <td>-8,806</td>
# <td>-3,604</td>
# <td>926</td>
# </tr>

# %%
trs[10]
# Out:
# <tr>
# <th class="h_th th_date"><span>날짜</span></th>
# <th class="h_th th_pass_price" scope="col"><span>종가</span></th>
# <th class="h_th th_pass_day" scope="col"><span>전일비</span></th>
# <th class="h_th th_foreigner" scope="col"><span>외국인</span></th>
# <th class="h_th th_organ" scope="col"><span>기관</span></th>
# </tr>

# %%
tds
# Out:
# [<th class="h_th2 th_cop_comp7" scope="row"><span>매출액(억)</span></th>]

# %%
for i in code_list[:10] :
    try:
        driver.get('https://finance.naver.com/item/main.nhn?code='+i)
        icon = driver.find_element_by_class_name("tit")
        icon.click()
        time.sleep(5)

        # 페이지소스 가져오기
        html = driver.page_source
        soup = BeautifulSoup(html)
        # 복지 및 급여
        welfare = soup.find_all(class_='txt_point')[0].text
        # 업무와 삶의 균형
        balance = soup.find_all(class_='txt_point')[1].text
        # 사내문화
        culture = soup.find_all(class_='txt_point')[2].text
        # 승진 기회 및 가능성
        possibility = soup.find_all(class_='txt_point')[3].text
        # 경영진
        executive = soup.find_all(class_='txt_point')[4].text
        # 총 만족도
        total = soup.find_all(class_='rate_point')[0].text
        name = soup.find_all(class_='word')[0].text
        dict = {'회사명':[i],'네임':[name],'복지':[welfare],'워라벨':[balance],'사내문화':[culture],'가능성':[possibility],'경영진':[executive],'총만족도':[total]}
        rating_box = rating_box.append(pd.DataFrame(dict))
    
    except: continue
